# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelKupfer/MAT421/blob/main/mat421_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 17 - Interpolation**
# ---

# %% [markdown]
# 17.1 Interpolation Problem Statement

# %% [markdown]
# The goal of interpolation is to find an estimation function such that y(xi) = yi. Given a new x^ we can interpolate its function value y(x^).

# %% [markdown]
# 17.2 Linear Interpolation

# %% [markdown]
# Find the linear interpolation of x = 3.5 based on the data x = [1,2,3,4,5], y = [7,3,6,5,7]

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

x = [1, 2, 3, 4, 5]
y = [7, 3, 6, 5 ,7]

f = interp1d(x, y)
y_hat = f(3.5)
print(y_hat)
# Out:
# 5.5

# %%
plt.figure(figsize = (10,8))
plt.plot(x, y, '-ob')
plt.plot(3.5, y_hat, 'ro')
plt.title('Linear Interpolation at x = 13.5')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# As seen in the graph above, linear interpolation assumes the estimated point is on the line that joins the nearest points to the left and right

# %% [markdown]
# 17.3 Cubic Spline Interpolation

# %% [markdown]
# Cubic Spline Interpolation assumes that each point is connected by a cubic polynomial. To determine the function you must first find the coefficients of the cubic polynomial which python can do with the cubicspline function.

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

x = [1, 3, 5, 7]
y = [4, 7, 2, 6]

# use bc_type = 'natural' adds the constraints as we described above
f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(1, 7, 100)
y_new = f(x_new)

plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# As seen above, there are four different points and so there are three different cubic polynomial fucntions between each of the points.
